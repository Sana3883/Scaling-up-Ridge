# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

mkl_execution_times = np.genfromtxt('mkl_execution_times_Parcel.csv', delimiter=',').tolist()
openblas_execution_times = np.genfromtxt('openblas_execution_times_Parcel.csv', delimiter=',').tolist()

num_processors = [1, 2, 4, 8, 16, 32]

# Calculate speed-up for each subject and BLAS library
mkl_speedup = [[mkl_execution_times[i][0] / time for time in mkl_execution_times[i]] for i in range(len(num_processors))]
openblas_speedup = [[openblas_execution_times[i][0] / time for time in openblas_execution_times[i]] for i in range(len(num_processors))]


mkl_color = list(mcolors.TABLEAU_COLORS.values())[0]
openblas_color = list(mcolors.TABLEAU_COLORS.values())[1]

# Plotting
plt.figure(figsize=(12, 8))

for i in range(len(num_processors)):
    
    plt.plot(num_processors, mkl_speedup[i], label='MKL' if i == 0 else None, marker='o', color=mkl_color)
    
    plt.plot(num_processors, openblas_speedup[i], label='OpenBLAS' if i == 0 else None, marker='o', color=openblas_color)
    
    plt.plot(num_processors, mkl_speedup[i], marker='o', color=mkl_color) if i != 0 else None
    
    plt.plot(num_processors, openblas_speedup[i], marker='o', color=openblas_color) if i != 0 else None

plt.xlabel('Number of Threads', fontsize=20)
plt.ylabel('Speed-Up', fontsize=20)
plt.legend(fontsize=12)
plt.grid(True)

# Increase the font size of numbers on the axes
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

mkl_execution_times = np.genfromtxt('mkl_execution_times_Parcel.csv', delimiter=',').tolist()
openblas_execution_times = np.genfromtxt('openblas_execution_times_Parcel.csv', delimiter=',').tolist()

num_processors = [1, 2, 4, 8, 16, 32]

# Calculate speed-up for each subject and BLAS library
mkl_speedup = [[mkl_execution_times[i][0] / time for time in mkl_execution_times[i]] for i in range(len(num_processors))]
openblas_speedup = [[openblas_execution_times[i][0] / time for time in openblas_execution_times[i]] for i in range(len(num_processors))]

efficiency_mkl = [[value / num_processors[i] for i, value in enumerate(row)] for row in mkl_speedup]

efficiency_openblas = [[value / num_processors[i] for i, value in enumerate(row)] for row in openblas_speedup ]

mkl_color = list(mcolors.TABLEAU_COLORS.values())[0]
openblas_color = list(mcolors.TABLEAU_COLORS.values())[1]

# Plotting
plt.figure(figsize=(12, 8))

for i in range(len(num_processors)):
    
    plt.plot(num_processors, efficiency_mkl[i], label='MKL' if i == 0 else None, marker='o', color=mkl_color)
    
    plt.plot(num_processors, efficiency_openblas[i], label='OpenBLAS' if i == 0 else None, marker='o', color=openblas_color)
    
    plt.plot(num_processors, efficiency_mkl[i], marker='o', color=mkl_color) if i != 0 else None
    
    plt.plot(num_processors, efficiency_openblas[i], marker='o', color=openblas_color) if i != 0 else None

plt.xlabel('Number of Threads', fontsize=20)
plt.ylabel('parallel Efficiency', fontsize=20)
plt.legend(fontsize=12)
plt.grid(True)

# Increase the font size of numbers on the axes
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.show()

# %%
print(openblas_speedup)
print(efficiency_openblas)
# Out:
# [[1.0, 1.8160642570281125, 2.6153846153846154, 3.5634357762017337, 4.198700092850511, 4.705515088449531], [1.0, 1.876916868442292, 2.6760644418872266, 3.5970610982211912, 4.387735849056604, 4.8196891191709845], [1.0, 1.8151909017059302, 2.493861607142857, 3.432411674347158, 4.244064577397911, 4.987723214285714], [1.0, 1.8684977111943404, 2.607433217189315, 3.3210059171597632, 4.432379072063179, 5.011160714285714], [1.0, 1.823743922204214, 2.5486976217440542, 3.51640625, 4.31957773512476, 4.688541666666667], [1.0, 1.80973630831643, 2.5203389830508476, 3.3415730337078653, 4.347953216374269, 4.666317991631799]]
# [[1.0, 0.9080321285140562, 0.6538461538461539, 0.4454294720252167, 0.26241875580315693, 0.14704734651404786], [1.0, 0.938458434221146, 0.6690161104718066, 0.4496326372776489, 0.27423349056603774, 0.15061528497409327], [1.0, 0.9075954508529651, 0.6234654017857143, 0.4290514592933948, 0.2652540360873694, 0.15586635044642858], [1.0, 0.9342488555971702, 0.6518583042973287, 0.4151257396449704, 0.27702369200394866, 0.15659877232142858], [1.0, 0.911871961102107, 0.6371744054360136, 0.43955078125, 0.2699736084452975, 0.14651692708333333], [1.0, 0.904868154158215, 0.6300847457627119, 0.41769662921348316, 0.2717470760233918, 0.14582243723849372]]

# %%
1.8160642570281125/2
# Out:
# 0.9080321285140562

# %%
4.347953216374269/16
# Out:
# 0.2717470760233918

# %%
4.8196891191709845/32
# Out:
# 0.15061528497409327

# %%
8.66597510373444/32
# Out:
# 0.2708117219917012

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

mkl_execution_times = np.genfromtxt('mkl_execution_times_ROI.csv', delimiter=',').tolist()
openblas_execution_times = np.genfromtxt('openblas_execution_times_ROI.csv', delimiter=',').tolist()

num_processors = [1, 2, 4, 8, 16, 32]

# Calculate speed-up for each subject and library
mkl_speedup = [[mkl_execution_times[i][0] / time for time in mkl_execution_times[i]] for i in range(len(num_processors))]
openblas_speedup = [[openblas_execution_times[i][0] / time for time in openblas_execution_times[i]] for i in range(len(num_processors))]

# Define colors for MKL and OpenBLAS
mkl_color = list(mcolors.TABLEAU_COLORS.values())[0]
openblas_color = list(mcolors.TABLEAU_COLORS.values())[1]

# Plotting
plt.figure(figsize=(12, 8))

for i in range(len(num_processors)):
    # Plot MKL
    plt.plot(num_processors, mkl_speedup[i], label='MKL' if i == 0 else None, marker='o', color=mkl_color)
    # Plot OpenBLAS
    plt.plot(num_processors, openblas_speedup[i], label='OpenBLAS' if i == 0 else None, marker='o', color=openblas_color)
    # Plot other subjects for MKL
    plt.plot(num_processors, mkl_speedup[i], marker='o', color=mkl_color) if i != 0 else None
    # Plot other subjects for OpenBLAS
    plt.plot(num_processors, openblas_speedup[i], marker='o', color=openblas_color) if i != 0 else None

plt.xlabel('Number of Threads', fontsize=20)
plt.ylabel('Speed-Up', fontsize=20)
plt.legend(fontsize=12)
plt.grid(True)

# Increase the font size of numbers on the axes
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

mkl_execution_times = np.genfromtxt('mkl_execution_times_ROI.csv', delimiter=',').tolist()
openblas_execution_times = np.genfromtxt('openblas_execution_times_ROI.csv', delimiter=',').tolist()

num_processors = [1, 2, 4, 8, 16, 32]

# Calculate speed-up for each subject and library
mkl_speedup = [[mkl_execution_times[i][0] / time for time in mkl_execution_times[i]] for i in range(len(num_processors))]
openblas_speedup = [[openblas_execution_times[i][0] / time for time in openblas_execution_times[i]] for i in range(len(num_processors))]

efficiency_mkl = [[value / num_processors[i] for i, value in enumerate(row)] for row in mkl_speedup]

efficiency_openblas = [[value / num_processors[i] for i, value in enumerate(row)] for row in openblas_speedup ]

# Define colors for MKL and OpenBLAS
mkl_color = list(mcolors.TABLEAU_COLORS.values())[0]
openblas_color = list(mcolors.TABLEAU_COLORS.values())[1]

# Plotting
plt.figure(figsize=(12, 8))

for i in range(len(num_processors)):
    # Plot MKL
    plt.plot(num_processors, efficiency_mkl[i], label='MKL' if i == 0 else None, marker='o', color=mkl_color)
    # Plot OpenBLAS
    plt.plot(num_processors, efficiency_openblas[i], label='OpenBLAS' if i == 0 else None, marker='o', color=openblas_color)
    # Plot other subjects for MKL
    plt.plot(num_processors, efficiency_mkl[i], marker='o', color=mkl_color) if i != 0 else None
    # Plot other subjects for OpenBLAS
    plt.plot(num_processors, efficiency_openblas[i], marker='o', color=openblas_color) if i != 0 else None

plt.xlabel('Number of Threads', fontsize=20)
plt.ylabel('parallel Efficiency', fontsize=20)
plt.legend(fontsize=12)
plt.grid(True)

# Increase the font size of numbers on the axes
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.show()

# %%
print(mkl_speedup)
print(efficiency_mkl)
# Out:
# [[1.0, 2.0613581523612545, 3.3957978421351505, 5.3061224489795915, 7.55050505050505, 9.242658423493046], [1.0, 1.9916107382550337, 3.3607021517553792, 5.332434860736748, 7.512658227848101, 9.541800643086816], [1.0, 1.951864406779661, 3.254946297343132, 5.011314186248912, 7.242767295597484, 9.31715210355987], [1.0, 2.0037124535943303, 3.3945111492281304, 4.9932716568545, 7.76078431372549, 9.453821656050955], [1.0, 2.0196943972835313, 3.430219146482122, 5.38768115942029, 7.6061381074168795, 9.136712749615976], [1.0, 1.9892110586648686, 3.424260011607661, 5.193661971830986, 7.742782152230971, 9.190031152647975]]
# [[1.0, 1.0306790761806273, 0.8489494605337876, 0.6632653061224489, 0.47190656565656564, 0.2888330757341577], [1.0, 0.9958053691275168, 0.8401755379388448, 0.6665543575920935, 0.46954113924050633, 0.298181270096463], [1.0, 0.9759322033898306, 0.813736574335783, 0.626414273281114, 0.45267295597484275, 0.29116100323624594], [1.0, 1.0018562267971651, 0.8486277873070326, 0.6241589571068125, 0.48504901960784313, 0.29543192675159236], [1.0, 1.0098471986417656, 0.8575547866205305, 0.6734601449275363, 0.47538363171355497, 0.28552227342549924], [1.0, 0.9946055293324343, 0.8560650029019152, 0.6492077464788732, 0.4839238845144357, 0.28718847352024923]]

# %%
5.011314186248912/8
# Out:
# 0.626414273281114

# %%
1.951864406779661/2
# Out:
# 0.9759322033898306

# %%
7.6061381074168795/16
# Out:
# 0.47538363171355497
